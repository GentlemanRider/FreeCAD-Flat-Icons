# %%
# Static SVG parts
svg = """<?xml version="1.0" encoding="UTF-8" standalone="no"?>
<!-- Created with Inkscape (http://www.inkscape.org/) -->

<svg
   width="48"
   height="48"
   viewBox="0 0 48.000001 48"
   version="1.1"
   id="svg1387"
   sodipodi:docname="DynamicData.svg"
   inkscape:version="1.3 (1:1.3+202307231459+0e150ed6c4)"
   xml:space="preserve"
   xmlns:inkscape="http://www.inkscape.org/namespaces/inkscape"
   xmlns:sodipodi="http://sodipodi.sourceforge.net/DTD/sodipodi-0.dtd"
   xmlns:xlink="http://www.w3.org/1999/xlink"
   xmlns="http://www.w3.org/2000/svg"
   xmlns:svg="http://www.w3.org/2000/svg"><sodipodi:namedview
     id="namedview10"
     pagecolor="#505050"
     bordercolor="#ffffff"
     borderopacity="1"
     inkscape:showpageshadow="0"
     inkscape:pageopacity="0"
     inkscape:pagecheckerboard="1"
     inkscape:deskcolor="#505050"
     showgrid="false"
     inkscape:zoom="1.2727922"
     inkscape:cx="-199.56125"
     inkscape:cy="-181.0979"
     inkscape:window-width="1711"
     inkscape:window-height="1022"
     inkscape:window-x="709"
     inkscape:window-y="383"
     inkscape:window-maximized="0"
     inkscape:current-layer="layer2"
     showguides="true">"""
def insertDefs():
    return """<defs
     id="FlatIconDefs"><style
       id="FlatIconStlyle"><![CDATA[{css}
]]></style></defs>""".format(css= insertCSS())

def insertCSS():
    return """
.IconOutline { stroke:#f5f4f4;  fill:none;  stroke-width:1.5; }
.ThinDotOutline { stroke-dasharray:0.1, 2.5;  stroke-linecap:round; }
.ThickDotOutline { stroke-dasharray:0.1, 5;  stroke-linecap:round;  stroke-width:3; }
.ThickOutline { stroke-linejoin:miter;  stroke-miterlimit:3;  stroke-width:3; }
.CornerButton { stroke-width: 8;  stroke-linejoin: round; }
.OutlineAsFill { fill: #f5f4f4; }
.MeshFillArea { fill:#7950f2; }
.MeshFillAreaDark { fill:#6b4cc8; }
.DynDataFillArea { fill:#aea72c; }
.PartFillArea { fill:#3769ff }
.BgFillArea { fill: #495057; }
.AdditiveFillArea { fill: #40c057 }
.SubtractArea { fill: #f03e3e; }
.IntersectArea { fill: #4c6ef5; }
.ImportArrow { fill:#40c057; }
.ExportArrow { fill:#f03e3e; }
.GenericArrow { fill:#F5F4F4; }
.SketchFill { fill: #f5f4f4; }
.SketckOutline { stroke:#f03e3e; }
.SpreadsheetFill { fill: #868e96; }
.SpreadsheetLines { stroke:#495057; }
.PlaceHolder{ fill: #555555; fill-opacity: 0.5;}"""

#svg += insertDefs()

# %%
print(svg)
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!-- Created with Inkscape (http://www.inkscape.org/) -->
#
# <svg
#    width="48"
#    height="48"
#    viewBox="0 0 48.000001 48"
#    version="1.1"
#    id="svg1387"
#    sodipodi:docname="DynamicData.svg"
#    inkscape:version="1.3 (1:1.3+202307231459+0e150ed6c4)"
#    xml:space="preserve"
#    xmlns:inkscape="http://www.inkscape.org/namespaces/inkscape"
#    xmlns:sodipodi="http://sodipodi.sourceforge.net/DTD/sodipodi-0.dtd"
#    xmlns:xlink="http://www.w3.org/1999/xlink"
#    xmlns="http://www.w3.org/2000/svg"
#    xmlns:svg="http://www.w3.org/2000/svg"><sodipodi:namedview
#      id="namedview10"
#      pagecolor="#505050"
#      bordercolor="#ffffff"
#      borderopacity="1"
#      inkscape:showpageshadow="0"
#      inkscape:pageopacity="0"
#      inkscape:pagecheckerboard="1"
#      inkscape:deskcolor="#505050"
#      showgrid="false"
#      inkscape:zoom="1.2727922"
#      inkscape:cx="-199.56125"
#      inkscape:cy="-181.0979"
#      inkscape:window-width="1711"
#      inkscape:window-height="1022"
#      inkscape:window-x="709"
#      inkscape:window-y="383"
#      inkscape:window-maximized="0"
#      inkscape:current-layer="layer2"
#      showguides="true">

# %%
import os
import argparse
import sys
import fnmatch
import re
key= "PartDesign"

def scand(direc,excludes):
    """
    Scan tree starting from direc
    """
    excludes = excludes or []
    excludes = r'|'.join([fnmatch.translate(x) for x in excludes]) or r'$.'

    resources = []
    for path, dirs, files in os.walk(direc):

        # exclude files
        files = [os.path.join(path, f) for f in files]
        files = [f for f in files if not re.match(excludes, f)]

        resources += files
    return resources
    #scan(resources)

def genPage(id, count):
    return """<inkscape:page
       x="0"
       y="{y}"
       width="48"
       height="48"
       id="page{c}"
       margin="0"
       bleed="0"
       inkscape:label="{i}" />""".format(i= id, c = count, y = int(count * 96))

def genPlaceHolder(id, count):
    return """<rect
         width="48"
         height="48"
         class="PlaceHolder"
         id="PH_{i}"
         x="0"
         y="{y}" />""".format(i= id, c = count, y = int(count * 96))

def genActFileQSS(id):
    return "select-by-id:PH_{i};fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Render/{i}.svg;export-do;select-clear;\n".format(i= id)
def genActFileLegacy(id):
    return "select-by-id:PH_{i};fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Legacy/{i}.svg;export-do;select-clear;\n".format(i= id)

# %%
pages = ""
placeholders = ""
actionFile = ""

res= scand(".", [])
count = 0
for r in res:
    if ".svg" in r:
        if key in r:
            splitpath = r.split("/")
            iconName = splitpath[len(splitpath)-1]
            iconName = iconName.split(".")[0]
            pages += genPage(iconName, count)
            placeholders += genPlaceHolder(iconName, count)
            actionFile +=  genActFileQSS(iconName)
            actionFile += genActFileLegacy(iconName) + "\n"
            count += 1
            #print(iconName)

# %%
#print(pages)
svg += pages +"</sodipodi:namedview>"
svg += insertDefs()
svg += """<g
     inkscape:label="Placeholders"
     inkscape:groupmode="layer"
     id="layer1">
     sodipodi:insensitive="true"
     style="display:none">"""
svg += placeholders + """ </g><g
     inkscape:groupmode="layer"
     id="layer2"
     inkscape:label="Icons" />
</svg>"""
print(svg)
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="no"?>
# <!-- Created with Inkscape (http://www.inkscape.org/) -->
#
# <svg
#    width="48"
#    height="48"
#    viewBox="0 0 48.000001 48"
#    version="1.1"
#    id="svg1387"
#    sodipodi:docname="DynamicData.svg"
#    inkscape:version="1.3 (1:1.3+202307231459+0e150ed6c4)"
#    xml:space="preserve"
#    xmlns:inkscape="http://www.inkscape.org/namespaces/inkscape"
#    xmlns:sodipodi="http://sodipodi.sourceforge.net/DTD/sodipodi-0.dtd"
#    xmlns:xlink="http://www.w3.org/1999/xlink"
#    xmlns="http://www.w3.org/2000/svg"
#    xmlns:svg="http://www.w3.org/2000/svg"><sodipodi:namedview
#      id="namedview10"
#      pagecolor="#505050"
#      bordercolor="#ffffff"
#      borderopacity="1"
#      inkscape:showpageshadow="0"
#      inkscape:pageopacity="0"
#      inkscape:pagecheckerboard="1"
#      inkscape:deskcolor="#505050"
#      showgrid="false"
#      inkscape:zoom="1.2727922"
#      inkscape:cx="-199.56125"
#      inkscape:cy="-181.0979"
#      inkscape:window-width="1711"
#      inkscape:window-height="1022"
#      inkscape:window-x="709"
#      inkscape:window-y="383"
#      inkscape:window-maximized="0"
#      inkscape:current-layer="layer2"
#      showguides="true"><inkscape:page
#        x="0"
#        y="0"
#        width="48"
#        height="48"
#        id="page0"
#        margin="0"
#        bleed="0"
#        inkscape:label="WizardShaft" /><inkscape:page
#        x="0"
#        y="96"
#        width="48"
#        height="48"
#        id="page1"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_SubtractiveSphere" /><inkscape:page
#        x="0"
#        y="192"
#        width="48"
#        height="48"
#        id="page2"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_SubtractiveEllipsoid" /><inkscape:page
#        x="0"
#        y="288"
#        width="48"
#        height="48"
#        id="page3"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_Mirrored" /><inkscape:page
#        x="0"
#        y="384"
#        width="48"
#        height="48"
#        id="page4"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_AdditiveHelix" /><inkscape:page
#        x="0"
#        y="480"
#        width="48"
#        height="48"
#        id="page5"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_AdditivePrism" /><inkscape:page
#        x="0"
#        y="576"
#        width="48"
#        height="48"
#        id="page6"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_Boolean" /><inkscape:page
#        x="0"
#        y="672"
#        width="48"
#        height="48"
#        id="page7"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_Hole" /><inkscape:page
#        x="0"
#        y="768"
#        width="48"
#        height="48"
#        id="page8"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_SubtractiveCylinder" /><inkscape:page
#        x="0"
#        y="864"
#        width="48"
#        height="48"
#        id="page9"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_Body" /><inkscape:page
#        x="0"
#        y="960"
#        width="48"
#        height="48"
#        id="page10"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_Fillet" /><inkscape:page
#        x="0"
#        y="1056"
#        width="48"
#        height="48"
#        id="page11"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_Clone" /><inkscape:page
#        x="0"
#        y="1152"
#        width="48"
#        height="48"
#        id="page12"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_PolarPattern" /><inkscape:page
#        x="0"
#        y="1248"
#        width="48"
#        height="48"
#        id="page13"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_InvoluteGear" /><inkscape:page
#        x="0"
#        y="1344"
#        width="48"
#        height="48"
#        id="page14"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_MoveFeatureInTree" /><inkscape:page
#        x="0"
#        y="1440"
#        width="48"
#        height="48"
#        id="page15"
#        margin="0"
#        bleed="0"
#        inkscape:label="Tree_PartDesign_Pad" /><inkscape:page
#        x="0"
#        y="1536"
#        width="48"
#        height="48"
#        id="page16"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_SubtractivePipe" /><inkscape:page
#        x="0"
#        y="1632"
#        width="48"
#        height="48"
#        id="page17"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_MultiTransform" /><inkscape:page
#        x="0"
#        y="1728"
#        width="48"
#        height="48"
#        id="page18"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_BaseFeature" /><inkscape:page
#        x="0"
#        y="1824"
#        width="48"
#        height="48"
#        id="page19"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_InternalExternalGear" /><inkscape:page
#        x="0"
#        y="1920"
#        width="48"
#        height="48"
#        id="page20"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_MoveTip" /><inkscape:page
#        x="0"
#        y="2016"
#        width="48"
#        height="48"
#        id="page21"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_Pocket" /><inkscape:page
#        x="0"
#        y="2112"
#        width="48"
#        height="48"
#        id="page22"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_Body_old" /><inkscape:page
#        x="0"
#        y="2208"
#        width="48"
#        height="48"
#        id="page23"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_SubtractiveWedge" /><inkscape:page
#        x="0"
#        y="2304"
#        width="48"
#        height="48"
#        id="page24"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_AdditiveEllipsoid" /><inkscape:page
#        x="0"
#        y="2400"
#        width="48"
#        height="48"
#        id="page25"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesignWorkbench" /><inkscape:page
#        x="0"
#        y="2496"
#        width="48"
#        height="48"
#        id="page26"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_CoordinateSystem" /><inkscape:page
#        x="0"
#        y="2592"
#        width="48"
#        height="48"
#        id="page27"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_Point" /><inkscape:page
#        x="0"
#        y="2688"
#        width="48"
#        height="48"
#        id="page28"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_SubtractivePrism" /><inkscape:page
#        x="0"
#        y="2784"
#        width="48"
#        height="48"
#        id="page29"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_Groove" /><inkscape:page
#        x="0"
#        y="2880"
#        width="48"
#        height="48"
#        id="page30"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_Thickness" /><inkscape:page
#        x="0"
#        y="2976"
#        width="48"
#        height="48"
#        id="page31"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_Pad" /><inkscape:page
#        x="0"
#        y="3072"
#        width="48"
#        height="48"
#        id="page32"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_Scaled" /><inkscape:page
#        x="0"
#        y="3168"
#        width="48"
#        height="48"
#        id="page33"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_AdditiveLoft" /><inkscape:page
#        x="0"
#        y="3264"
#        width="48"
#        height="48"
#        id="page34"
#        margin="0"
#        bleed="0"
#        inkscape:label="Tree_PartDesign_Revolution" /><inkscape:page
#        x="0"
#        y="3360"
#        width="48"
#        height="48"
#        id="page35"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_SubtractiveLoft" /><inkscape:page
#        x="0"
#        y="3456"
#        width="48"
#        height="48"
#        id="page36"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_AdditiveWedge" /><inkscape:page
#        x="0"
#        y="3552"
#        width="48"
#        height="48"
#        id="page37"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_Chamfer" /><inkscape:page
#        x="0"
#        y="3648"
#        width="48"
#        height="48"
#        id="page38"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_Migrate" /><inkscape:page
#        x="0"
#        y="3744"
#        width="48"
#        height="48"
#        id="page39"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_SubtractiveCone" /><inkscape:page
#        x="0"
#        y="3840"
#        width="48"
#        height="48"
#        id="page40"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_MoveFeature" /><inkscape:page
#        x="0"
#        y="3936"
#        width="48"
#        height="48"
#        id="page41"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_ShapeBinder" /><inkscape:page
#        x="0"
#        y="4032"
#        width="48"
#        height="48"
#        id="page42"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_Revolution" /><inkscape:page
#        x="0"
#        y="4128"
#        width="48"
#        height="48"
#        id="page43"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_Sprocket" /><inkscape:page
#        x="0"
#        y="4224"
#        width="48"
#        height="48"
#        id="page44"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_AdditiveCone" /><inkscape:page
#        x="0"
#        y="4320"
#        width="48"
#        height="48"
#        id="page45"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_SubtractiveHelix" /><inkscape:page
#        x="0"
#        y="4416"
#        width="48"
#        height="48"
#        id="page46"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_AdditiveTorus" /><inkscape:page
#        x="0"
#        y="4512"
#        width="48"
#        height="48"
#        id="page47"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_Flip_Direction" /><inkscape:page
#        x="0"
#        y="4608"
#        width="48"
#        height="48"
#        id="page48"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_AdditiveBox" /><inkscape:page
#        x="0"
#        y="4704"
#        width="48"
#        height="48"
#        id="page49"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_SubShapeBinder" /><inkscape:page
#        x="0"
#        y="4800"
#        width="48"
#        height="48"
#        id="page50"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_Plane" /><inkscape:page
#        x="0"
#        y="4896"
#        width="48"
#        height="48"
#        id="page51"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_AdditiveCylinder" /><inkscape:page
#        x="0"
#        y="4992"
#        width="48"
#        height="48"
#        id="page52"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_SubtractiveBox" /><inkscape:page
#        x="0"
#        y="5088"
#        width="48"
#        height="48"
#        id="page53"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_LinearPattern" /><inkscape:page
#        x="0"
#        y="5184"
#        width="48"
#        height="48"
#        id="page54"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_Line" /><inkscape:page
#        x="0"
#        y="5280"
#        width="48"
#        height="48"
#        id="page55"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_Body_Tree" /><inkscape:page
#        x="0"
#        y="5376"
#        width="48"
#        height="48"
#        id="page56"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_SubtractiveTorus" /><inkscape:page
#        x="0"
#        y="5472"
#        width="48"
#        height="48"
#        id="page57"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_Draft" /><inkscape:page
#        x="0"
#        y="5568"
#        width="48"
#        height="48"
#        id="page58"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_AdditiveSphere" /><inkscape:page
#        x="0"
#        y="5664"
#        width="48"
#        height="48"
#        id="page59"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_AdditivePipe" /></sodipodi:namedview><defs
#      id="FlatIconDefs"><style
#        id="FlatIconStlyle"><![CDATA[
# .IconOutline { stroke:#f5f4f4;  fill:none;  stroke-width:1.5; }
# .ThinDotOutline { stroke-dasharray:0.1, 2.5;  stroke-linecap:round; }
# .ThickDotOutline { stroke-dasharray:0.1, 5;  stroke-linecap:round;  stroke-width:3; }
# .ThickOutline { stroke-linejoin:miter;  stroke-miterlimit:3;  stroke-width:3; }
# .CornerButton { stroke-width: 8;  stroke-linejoin: round; }
# .OutlineAsFill { fill: #f5f4f4; }
# .MeshFillArea { fill:#7950f2; }
# .MeshFillAreaDark { fill:#6b4cc8; }
# .DynDataFillArea { fill:#aea72c; }
# .PartFillArea { fill:#3769ff }
# .BgFillArea { fill: #495057; }
# .AdditiveFillArea { fill: #40c057 }
# .SubtractArea { fill: #f03e3e; }
# .IntersectArea { fill: #4c6ef5; }
# .ImportArrow { fill:#40c057; }
# .ExportArrow { fill:#f03e3e; }
# .GenericArrow { fill:#F5F4F4; }
# .SketchFill { fill: #f5f4f4; }
# .SketckOutline { stroke:#f03e3e; }
# .SpreadsheetFill { fill: #868e96; }
# .SpreadsheetLines { stroke:#495057; }
# .PlaceHolder{ fill: #555555; fill-opacity: 0.5;}
# ]]></style></defs><g
#      inkscape:label="Placeholders"
#      inkscape:groupmode="layer"
#      id="layer1">
#      sodipodi:insensitive="true"
#      style="display:none"><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_WizardShaft"
#          x="0"
#          y="0" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_SubtractiveSphere"
#          x="0"
#          y="96" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_SubtractiveEllipsoid"
#          x="0"
#          y="192" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_Mirrored"
#          x="0"
#          y="288" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_AdditiveHelix"
#          x="0"
#          y="384" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_AdditivePrism"
#          x="0"
#          y="480" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_Boolean"
#          x="0"
#          y="576" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_Hole"
#          x="0"
#          y="672" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_SubtractiveCylinder"
#          x="0"
#          y="768" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_Body"
#          x="0"
#          y="864" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_Fillet"
#          x="0"
#          y="960" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_Clone"
#          x="0"
#          y="1056" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_PolarPattern"
#          x="0"
#          y="1152" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_InvoluteGear"
#          x="0"
#          y="1248" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_MoveFeatureInTree"
#          x="0"
#          y="1344" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_Tree_PartDesign_Pad"
#          x="0"
#          y="1440" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_SubtractivePipe"
#          x="0"
#          y="1536" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_MultiTransform"
#          x="0"
#          y="1632" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_BaseFeature"
#          x="0"
#          y="1728" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_InternalExternalGear"
#          x="0"
#          y="1824" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_MoveTip"
#          x="0"
#          y="1920" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_Pocket"
#          x="0"
#          y="2016" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_Body_old"
#          x="0"
#          y="2112" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_SubtractiveWedge"
#          x="0"
#          y="2208" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_AdditiveEllipsoid"
#          x="0"
#          y="2304" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesignWorkbench"
#          x="0"
#          y="2400" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_CoordinateSystem"
#          x="0"
#          y="2496" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_Point"
#          x="0"
#          y="2592" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_SubtractivePrism"
#          x="0"
#          y="2688" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_Groove"
#          x="0"
#          y="2784" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_Thickness"
#          x="0"
#          y="2880" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_Pad"
#          x="0"
#          y="2976" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_Scaled"
#          x="0"
#          y="3072" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_AdditiveLoft"
#          x="0"
#          y="3168" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_Tree_PartDesign_Revolution"
#          x="0"
#          y="3264" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_SubtractiveLoft"
#          x="0"
#          y="3360" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_AdditiveWedge"
#          x="0"
#          y="3456" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_Chamfer"
#          x="0"
#          y="3552" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_Migrate"
#          x="0"
#          y="3648" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_SubtractiveCone"
#          x="0"
#          y="3744" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_MoveFeature"
#          x="0"
#          y="3840" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_ShapeBinder"
#          x="0"
#          y="3936" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_Revolution"
#          x="0"
#          y="4032" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_Sprocket"
#          x="0"
#          y="4128" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_AdditiveCone"
#          x="0"
#          y="4224" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_SubtractiveHelix"
#          x="0"
#          y="4320" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_AdditiveTorus"
#          x="0"
#          y="4416" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_Flip_Direction"
#          x="0"
#          y="4512" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_AdditiveBox"
#          x="0"
#          y="4608" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_SubShapeBinder"
#          x="0"
#          y="4704" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_Plane"
#          x="0"
#          y="4800" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_AdditiveCylinder"
#          x="0"
#          y="4896" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_SubtractiveBox"
#          x="0"
#          y="4992" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_LinearPattern"
#          x="0"
#          y="5088" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_Line"
#          x="0"
#          y="5184" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_Body_Tree"
#          x="0"
#          y="5280" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_SubtractiveTorus"
#          x="0"
#          y="5376" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_Draft"
#          x="0"
#          y="5472" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_AdditiveSphere"
#          x="0"
#          y="5568" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_AdditivePipe"
#          x="0"
#          y="5664" /> </g><g
#      inkscape:groupmode="layer"
#      id="layer2"
#      inkscape:label="Icons" />
# </svg><inkscape:page
#        x="0"
#        y="0"
#        width="48"
#        height="48"
#        id="page0"
#        margin="0"
#        bleed="0"
#        inkscape:label="WizardShaft" /><inkscape:page
#        x="0"
#        y="96"
#        width="48"
#        height="48"
#        id="page1"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_SubtractiveSphere" /><inkscape:page
#        x="0"
#        y="192"
#        width="48"
#        height="48"
#        id="page2"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_SubtractiveEllipsoid" /><inkscape:page
#        x="0"
#        y="288"
#        width="48"
#        height="48"
#        id="page3"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_Mirrored" /><inkscape:page
#        x="0"
#        y="384"
#        width="48"
#        height="48"
#        id="page4"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_AdditiveHelix" /><inkscape:page
#        x="0"
#        y="480"
#        width="48"
#        height="48"
#        id="page5"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_AdditivePrism" /><inkscape:page
#        x="0"
#        y="576"
#        width="48"
#        height="48"
#        id="page6"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_Boolean" /><inkscape:page
#        x="0"
#        y="672"
#        width="48"
#        height="48"
#        id="page7"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_Hole" /><inkscape:page
#        x="0"
#        y="768"
#        width="48"
#        height="48"
#        id="page8"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_SubtractiveCylinder" /><inkscape:page
#        x="0"
#        y="864"
#        width="48"
#        height="48"
#        id="page9"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_Body" /><inkscape:page
#        x="0"
#        y="960"
#        width="48"
#        height="48"
#        id="page10"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_Fillet" /><inkscape:page
#        x="0"
#        y="1056"
#        width="48"
#        height="48"
#        id="page11"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_Clone" /><inkscape:page
#        x="0"
#        y="1152"
#        width="48"
#        height="48"
#        id="page12"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_PolarPattern" /><inkscape:page
#        x="0"
#        y="1248"
#        width="48"
#        height="48"
#        id="page13"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_InvoluteGear" /><inkscape:page
#        x="0"
#        y="1344"
#        width="48"
#        height="48"
#        id="page14"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_MoveFeatureInTree" /><inkscape:page
#        x="0"
#        y="1440"
#        width="48"
#        height="48"
#        id="page15"
#        margin="0"
#        bleed="0"
#        inkscape:label="Tree_PartDesign_Pad" /><inkscape:page
#        x="0"
#        y="1536"
#        width="48"
#        height="48"
#        id="page16"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_SubtractivePipe" /><inkscape:page
#        x="0"
#        y="1632"
#        width="48"
#        height="48"
#        id="page17"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_MultiTransform" /><inkscape:page
#        x="0"
#        y="1728"
#        width="48"
#        height="48"
#        id="page18"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_BaseFeature" /><inkscape:page
#        x="0"
#        y="1824"
#        width="48"
#        height="48"
#        id="page19"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_InternalExternalGear" /><inkscape:page
#        x="0"
#        y="1920"
#        width="48"
#        height="48"
#        id="page20"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_MoveTip" /><inkscape:page
#        x="0"
#        y="2016"
#        width="48"
#        height="48"
#        id="page21"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_Pocket" /><inkscape:page
#        x="0"
#        y="2112"
#        width="48"
#        height="48"
#        id="page22"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_Body_old" /><inkscape:page
#        x="0"
#        y="2208"
#        width="48"
#        height="48"
#        id="page23"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_SubtractiveWedge" /><inkscape:page
#        x="0"
#        y="2304"
#        width="48"
#        height="48"
#        id="page24"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_AdditiveEllipsoid" /><inkscape:page
#        x="0"
#        y="2400"
#        width="48"
#        height="48"
#        id="page25"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesignWorkbench" /><inkscape:page
#        x="0"
#        y="2496"
#        width="48"
#        height="48"
#        id="page26"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_CoordinateSystem" /><inkscape:page
#        x="0"
#        y="2592"
#        width="48"
#        height="48"
#        id="page27"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_Point" /><inkscape:page
#        x="0"
#        y="2688"
#        width="48"
#        height="48"
#        id="page28"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_SubtractivePrism" /><inkscape:page
#        x="0"
#        y="2784"
#        width="48"
#        height="48"
#        id="page29"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_Groove" /><inkscape:page
#        x="0"
#        y="2880"
#        width="48"
#        height="48"
#        id="page30"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_Thickness" /><inkscape:page
#        x="0"
#        y="2976"
#        width="48"
#        height="48"
#        id="page31"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_Pad" /><inkscape:page
#        x="0"
#        y="3072"
#        width="48"
#        height="48"
#        id="page32"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_Scaled" /><inkscape:page
#        x="0"
#        y="3168"
#        width="48"
#        height="48"
#        id="page33"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_AdditiveLoft" /><inkscape:page
#        x="0"
#        y="3264"
#        width="48"
#        height="48"
#        id="page34"
#        margin="0"
#        bleed="0"
#        inkscape:label="Tree_PartDesign_Revolution" /><inkscape:page
#        x="0"
#        y="3360"
#        width="48"
#        height="48"
#        id="page35"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_SubtractiveLoft" /><inkscape:page
#        x="0"
#        y="3456"
#        width="48"
#        height="48"
#        id="page36"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_AdditiveWedge" /><inkscape:page
#        x="0"
#        y="3552"
#        width="48"
#        height="48"
#        id="page37"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_Chamfer" /><inkscape:page
#        x="0"
#        y="3648"
#        width="48"
#        height="48"
#        id="page38"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_Migrate" /><inkscape:page
#        x="0"
#        y="3744"
#        width="48"
#        height="48"
#        id="page39"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_SubtractiveCone" /><inkscape:page
#        x="0"
#        y="3840"
#        width="48"
#        height="48"
#        id="page40"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_MoveFeature" /><inkscape:page
#        x="0"
#        y="3936"
#        width="48"
#        height="48"
#        id="page41"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_ShapeBinder" /><inkscape:page
#        x="0"
#        y="4032"
#        width="48"
#        height="48"
#        id="page42"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_Revolution" /><inkscape:page
#        x="0"
#        y="4128"
#        width="48"
#        height="48"
#        id="page43"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_Sprocket" /><inkscape:page
#        x="0"
#        y="4224"
#        width="48"
#        height="48"
#        id="page44"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_AdditiveCone" /><inkscape:page
#        x="0"
#        y="4320"
#        width="48"
#        height="48"
#        id="page45"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_SubtractiveHelix" /><inkscape:page
#        x="0"
#        y="4416"
#        width="48"
#        height="48"
#        id="page46"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_AdditiveTorus" /><inkscape:page
#        x="0"
#        y="4512"
#        width="48"
#        height="48"
#        id="page47"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_Flip_Direction" /><inkscape:page
#        x="0"
#        y="4608"
#        width="48"
#        height="48"
#        id="page48"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_AdditiveBox" /><inkscape:page
#        x="0"
#        y="4704"
#        width="48"
#        height="48"
#        id="page49"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_SubShapeBinder" /><inkscape:page
#        x="0"
#        y="4800"
#        width="48"
#        height="48"
#        id="page50"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_Plane" /><inkscape:page
#        x="0"
#        y="4896"
#        width="48"
#        height="48"
#        id="page51"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_AdditiveCylinder" /><inkscape:page
#        x="0"
#        y="4992"
#        width="48"
#        height="48"
#        id="page52"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_SubtractiveBox" /><inkscape:page
#        x="0"
#        y="5088"
#        width="48"
#        height="48"
#        id="page53"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_LinearPattern" /><inkscape:page
#        x="0"
#        y="5184"
#        width="48"
#        height="48"
#        id="page54"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_Line" /><inkscape:page
#        x="0"
#        y="5280"
#        width="48"
#        height="48"
#        id="page55"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_Body_Tree" /><inkscape:page
#        x="0"
#        y="5376"
#        width="48"
#        height="48"
#        id="page56"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_SubtractiveTorus" /><inkscape:page
#        x="0"
#        y="5472"
#        width="48"
#        height="48"
#        id="page57"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_Draft" /><inkscape:page
#        x="0"
#        y="5568"
#        width="48"
#        height="48"
#        id="page58"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_AdditiveSphere" /><inkscape:page
#        x="0"
#        y="5664"
#        width="48"
#        height="48"
#        id="page59"
#        margin="0"
#        bleed="0"
#        inkscape:label="PartDesign_AdditivePipe" /></sodipodi:namedview><defs
#      id="FlatIconDefs"><style
#        id="FlatIconStlyle"><![CDATA[
# .IconOutline { stroke:#f5f4f4;  fill:none;  stroke-width:1.5; }
# .ThinDotOutline { stroke-dasharray:0.1, 2.5;  stroke-linecap:round; }
# .ThickDotOutline { stroke-dasharray:0.1, 5;  stroke-linecap:round;  stroke-width:3; }
# .ThickOutline { stroke-linejoin:miter;  stroke-miterlimit:3;  stroke-width:3; }
# .CornerButton { stroke-width: 8;  stroke-linejoin: round; }
# .OutlineAsFill { fill: #f5f4f4; }
# .MeshFillArea { fill:#7950f2; }
# .MeshFillAreaDark { fill:#6b4cc8; }
# .DynDataFillArea { fill:#aea72c; }
# .PartFillArea { fill:#3769ff }
# .BgFillArea { fill: #495057; }
# .AdditiveFillArea { fill: #40c057 }
# .SubtractArea { fill: #f03e3e; }
# .IntersectArea { fill: #4c6ef5; }
# .ImportArrow { fill:#40c057; }
# .ExportArrow { fill:#f03e3e; }
# .GenericArrow { fill:#F5F4F4; }
# .SketchFill { fill: #f5f4f4; }
# .SketckOutline { stroke:#f03e3e; }
# .SpreadsheetFill { fill: #868e96; }
# .SpreadsheetLines { stroke:#495057; }
# .PlaceHolder{ fill: #555555; fill-opacity: 0.5;}
# ]]></style></defs><g
#      inkscape:label="Placeholders"
#      inkscape:groupmode="layer"
#      id="layer1">
#      sodipodi:insensitive="true"
#      style="display:none"><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_WizardShaft"
#          x="0"
#          y="0" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_SubtractiveSphere"
#          x="0"
#          y="96" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_SubtractiveEllipsoid"
#          x="0"
#          y="192" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_Mirrored"
#          x="0"
#          y="288" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_AdditiveHelix"
#          x="0"
#          y="384" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_AdditivePrism"
#          x="0"
#          y="480" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_Boolean"
#          x="0"
#          y="576" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_Hole"
#          x="0"
#          y="672" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_SubtractiveCylinder"
#          x="0"
#          y="768" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_Body"
#          x="0"
#          y="864" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_Fillet"
#          x="0"
#          y="960" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_Clone"
#          x="0"
#          y="1056" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_PolarPattern"
#          x="0"
#          y="1152" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_InvoluteGear"
#          x="0"
#          y="1248" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_MoveFeatureInTree"
#          x="0"
#          y="1344" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_Tree_PartDesign_Pad"
#          x="0"
#          y="1440" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_SubtractivePipe"
#          x="0"
#          y="1536" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_MultiTransform"
#          x="0"
#          y="1632" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_BaseFeature"
#          x="0"
#          y="1728" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_InternalExternalGear"
#          x="0"
#          y="1824" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_MoveTip"
#          x="0"
#          y="1920" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_Pocket"
#          x="0"
#          y="2016" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_Body_old"
#          x="0"
#          y="2112" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_SubtractiveWedge"
#          x="0"
#          y="2208" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_AdditiveEllipsoid"
#          x="0"
#          y="2304" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesignWorkbench"
#          x="0"
#          y="2400" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_CoordinateSystem"
#          x="0"
#          y="2496" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_Point"
#          x="0"
#          y="2592" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_SubtractivePrism"
#          x="0"
#          y="2688" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_Groove"
#          x="0"
#          y="2784" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_Thickness"
#          x="0"
#          y="2880" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_Pad"
#          x="0"
#          y="2976" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_Scaled"
#          x="0"
#          y="3072" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_AdditiveLoft"
#          x="0"
#          y="3168" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_Tree_PartDesign_Revolution"
#          x="0"
#          y="3264" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_SubtractiveLoft"
#          x="0"
#          y="3360" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_AdditiveWedge"
#          x="0"
#          y="3456" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_Chamfer"
#          x="0"
#          y="3552" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_Migrate"
#          x="0"
#          y="3648" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_SubtractiveCone"
#          x="0"
#          y="3744" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_MoveFeature"
#          x="0"
#          y="3840" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_ShapeBinder"
#          x="0"
#          y="3936" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_Revolution"
#          x="0"
#          y="4032" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_Sprocket"
#          x="0"
#          y="4128" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_AdditiveCone"
#          x="0"
#          y="4224" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_SubtractiveHelix"
#          x="0"
#          y="4320" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_AdditiveTorus"
#          x="0"
#          y="4416" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_Flip_Direction"
#          x="0"
#          y="4512" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_AdditiveBox"
#          x="0"
#          y="4608" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_SubShapeBinder"
#          x="0"
#          y="4704" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_Plane"
#          x="0"
#          y="4800" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_AdditiveCylinder"
#          x="0"
#          y="4896" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_SubtractiveBox"
#          x="0"
#          y="4992" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_LinearPattern"
#          x="0"
#          y="5088" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_Line"
#          x="0"
#          y="5184" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_Body_Tree"
#          x="0"
#          y="5280" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_SubtractiveTorus"
#          x="0"
#          y="5376" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_Draft"
#          x="0"
#          y="5472" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_AdditiveSphere"
#          x="0"
#          y="5568" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_AdditivePipe"
#          x="0"
#          y="5664" /> </g><g
#      inkscape:groupmode="layer"
#      id="layer2"
#      inkscape:label="Icons" />
# </svg>

# %%
print(placeholders)
# Out:
# <rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_WizardShaft"
#          x="0"
#          y="0" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_SubtractiveSphere"
#          x="0"
#          y="96" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_SubtractiveEllipsoid"
#          x="0"
#          y="192" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_Mirrored"
#          x="0"
#          y="288" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_AdditiveHelix"
#          x="0"
#          y="384" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_AdditivePrism"
#          x="0"
#          y="480" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_Boolean"
#          x="0"
#          y="576" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_Hole"
#          x="0"
#          y="672" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_SubtractiveCylinder"
#          x="0"
#          y="768" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_Body"
#          x="0"
#          y="864" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_Fillet"
#          x="0"
#          y="960" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_Clone"
#          x="0"
#          y="1056" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_PolarPattern"
#          x="0"
#          y="1152" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_InvoluteGear"
#          x="0"
#          y="1248" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_MoveFeatureInTree"
#          x="0"
#          y="1344" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_Tree_PartDesign_Pad"
#          x="0"
#          y="1440" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_SubtractivePipe"
#          x="0"
#          y="1536" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_MultiTransform"
#          x="0"
#          y="1632" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_BaseFeature"
#          x="0"
#          y="1728" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_InternalExternalGear"
#          x="0"
#          y="1824" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_MoveTip"
#          x="0"
#          y="1920" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_Pocket"
#          x="0"
#          y="2016" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_Body_old"
#          x="0"
#          y="2112" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_SubtractiveWedge"
#          x="0"
#          y="2208" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_AdditiveEllipsoid"
#          x="0"
#          y="2304" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesignWorkbench"
#          x="0"
#          y="2400" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_CoordinateSystem"
#          x="0"
#          y="2496" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_Point"
#          x="0"
#          y="2592" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_SubtractivePrism"
#          x="0"
#          y="2688" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_Groove"
#          x="0"
#          y="2784" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_Thickness"
#          x="0"
#          y="2880" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_Pad"
#          x="0"
#          y="2976" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_Scaled"
#          x="0"
#          y="3072" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_AdditiveLoft"
#          x="0"
#          y="3168" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_Tree_PartDesign_Revolution"
#          x="0"
#          y="3264" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_SubtractiveLoft"
#          x="0"
#          y="3360" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_AdditiveWedge"
#          x="0"
#          y="3456" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_Chamfer"
#          x="0"
#          y="3552" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_Migrate"
#          x="0"
#          y="3648" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_SubtractiveCone"
#          x="0"
#          y="3744" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_MoveFeature"
#          x="0"
#          y="3840" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_ShapeBinder"
#          x="0"
#          y="3936" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_Revolution"
#          x="0"
#          y="4032" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_Sprocket"
#          x="0"
#          y="4128" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_AdditiveCone"
#          x="0"
#          y="4224" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_SubtractiveHelix"
#          x="0"
#          y="4320" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_AdditiveTorus"
#          x="0"
#          y="4416" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_Flip_Direction"
#          x="0"
#          y="4512" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_AdditiveBox"
#          x="0"
#          y="4608" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_SubShapeBinder"
#          x="0"
#          y="4704" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_Plane"
#          x="0"
#          y="4800" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_AdditiveCylinder"
#          x="0"
#          y="4896" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_SubtractiveBox"
#          x="0"
#          y="4992" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_LinearPattern"
#          x="0"
#          y="5088" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_Line"
#          x="0"
#          y="5184" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_Body_Tree"
#          x="0"
#          y="5280" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_SubtractiveTorus"
#          x="0"
#          y="5376" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_Draft"
#          x="0"
#          y="5472" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_AdditiveSphere"
#          x="0"
#          y="5568" /><rect
#          width="48"
#          height="48"
#          class="PlaceHolder"
#          id="PH_PartDesign_AdditivePipe"
#          x="0"
#          y="5664" />

# %%
print(actionFile)
# Out:
# select-by-id:PH_WizardShaft;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Render/WizardShaft.svg;export-do;select-clear;
# select-by-id:PH_WizardShaft;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Legacy/WizardShaft.svg;export-do;select-clear;
#
# select-by-id:PH_PartDesign_SubtractiveSphere;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Render/PartDesign_SubtractiveSphere.svg;export-do;select-clear;
# select-by-id:PH_PartDesign_SubtractiveSphere;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Legacy/PartDesign_SubtractiveSphere.svg;export-do;select-clear;
#
# select-by-id:PH_PartDesign_SubtractiveEllipsoid;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Render/PartDesign_SubtractiveEllipsoid.svg;export-do;select-clear;
# select-by-id:PH_PartDesign_SubtractiveEllipsoid;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Legacy/PartDesign_SubtractiveEllipsoid.svg;export-do;select-clear;
#
# select-by-id:PH_PartDesign_Mirrored;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Render/PartDesign_Mirrored.svg;export-do;select-clear;
# select-by-id:PH_PartDesign_Mirrored;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Legacy/PartDesign_Mirrored.svg;export-do;select-clear;
#
# select-by-id:PH_PartDesign_AdditiveHelix;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Render/PartDesign_AdditiveHelix.svg;export-do;select-clear;
# select-by-id:PH_PartDesign_AdditiveHelix;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Legacy/PartDesign_AdditiveHelix.svg;export-do;select-clear;
#
# select-by-id:PH_PartDesign_AdditivePrism;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Render/PartDesign_AdditivePrism.svg;export-do;select-clear;
# select-by-id:PH_PartDesign_AdditivePrism;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Legacy/PartDesign_AdditivePrism.svg;export-do;select-clear;
#
# select-by-id:PH_PartDesign_Boolean;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Render/PartDesign_Boolean.svg;export-do;select-clear;
# select-by-id:PH_PartDesign_Boolean;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Legacy/PartDesign_Boolean.svg;export-do;select-clear;
#
# select-by-id:PH_PartDesign_Hole;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Render/PartDesign_Hole.svg;export-do;select-clear;
# select-by-id:PH_PartDesign_Hole;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Legacy/PartDesign_Hole.svg;export-do;select-clear;
#
# select-by-id:PH_PartDesign_SubtractiveCylinder;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Render/PartDesign_SubtractiveCylinder.svg;export-do;select-clear;
# select-by-id:PH_PartDesign_SubtractiveCylinder;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Legacy/PartDesign_SubtractiveCylinder.svg;export-do;select-clear;
#
# select-by-id:PH_PartDesign_Body;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Render/PartDesign_Body.svg;export-do;select-clear;
# select-by-id:PH_PartDesign_Body;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Legacy/PartDesign_Body.svg;export-do;select-clear;
#
# select-by-id:PH_PartDesign_Fillet;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Render/PartDesign_Fillet.svg;export-do;select-clear;
# select-by-id:PH_PartDesign_Fillet;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Legacy/PartDesign_Fillet.svg;export-do;select-clear;
#
# select-by-id:PH_PartDesign_Clone;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Render/PartDesign_Clone.svg;export-do;select-clear;
# select-by-id:PH_PartDesign_Clone;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Legacy/PartDesign_Clone.svg;export-do;select-clear;
#
# select-by-id:PH_PartDesign_PolarPattern;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Render/PartDesign_PolarPattern.svg;export-do;select-clear;
# select-by-id:PH_PartDesign_PolarPattern;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Legacy/PartDesign_PolarPattern.svg;export-do;select-clear;
#
# select-by-id:PH_PartDesign_InvoluteGear;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Render/PartDesign_InvoluteGear.svg;export-do;select-clear;
# select-by-id:PH_PartDesign_InvoluteGear;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Legacy/PartDesign_InvoluteGear.svg;export-do;select-clear;
#
# select-by-id:PH_PartDesign_MoveFeatureInTree;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Render/PartDesign_MoveFeatureInTree.svg;export-do;select-clear;
# select-by-id:PH_PartDesign_MoveFeatureInTree;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Legacy/PartDesign_MoveFeatureInTree.svg;export-do;select-clear;
#
# select-by-id:PH_Tree_PartDesign_Pad;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Render/Tree_PartDesign_Pad.svg;export-do;select-clear;
# select-by-id:PH_Tree_PartDesign_Pad;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Legacy/Tree_PartDesign_Pad.svg;export-do;select-clear;
#
# select-by-id:PH_PartDesign_SubtractivePipe;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Render/PartDesign_SubtractivePipe.svg;export-do;select-clear;
# select-by-id:PH_PartDesign_SubtractivePipe;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Legacy/PartDesign_SubtractivePipe.svg;export-do;select-clear;
#
# select-by-id:PH_PartDesign_MultiTransform;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Render/PartDesign_MultiTransform.svg;export-do;select-clear;
# select-by-id:PH_PartDesign_MultiTransform;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Legacy/PartDesign_MultiTransform.svg;export-do;select-clear;
#
# select-by-id:PH_PartDesign_BaseFeature;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Render/PartDesign_BaseFeature.svg;export-do;select-clear;
# select-by-id:PH_PartDesign_BaseFeature;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Legacy/PartDesign_BaseFeature.svg;export-do;select-clear;
#
# select-by-id:PH_PartDesign_InternalExternalGear;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Render/PartDesign_InternalExternalGear.svg;export-do;select-clear;
# select-by-id:PH_PartDesign_InternalExternalGear;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Legacy/PartDesign_InternalExternalGear.svg;export-do;select-clear;
#
# select-by-id:PH_PartDesign_MoveTip;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Render/PartDesign_MoveTip.svg;export-do;select-clear;
# select-by-id:PH_PartDesign_MoveTip;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Legacy/PartDesign_MoveTip.svg;export-do;select-clear;
#
# select-by-id:PH_PartDesign_Pocket;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Render/PartDesign_Pocket.svg;export-do;select-clear;
# select-by-id:PH_PartDesign_Pocket;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Legacy/PartDesign_Pocket.svg;export-do;select-clear;
#
# select-by-id:PH_PartDesign_Body_old;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Render/PartDesign_Body_old.svg;export-do;select-clear;
# select-by-id:PH_PartDesign_Body_old;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Legacy/PartDesign_Body_old.svg;export-do;select-clear;
#
# select-by-id:PH_PartDesign_SubtractiveWedge;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Render/PartDesign_SubtractiveWedge.svg;export-do;select-clear;
# select-by-id:PH_PartDesign_SubtractiveWedge;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Legacy/PartDesign_SubtractiveWedge.svg;export-do;select-clear;
#
# select-by-id:PH_PartDesign_AdditiveEllipsoid;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Render/PartDesign_AdditiveEllipsoid.svg;export-do;select-clear;
# select-by-id:PH_PartDesign_AdditiveEllipsoid;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Legacy/PartDesign_AdditiveEllipsoid.svg;export-do;select-clear;
#
# select-by-id:PH_PartDesignWorkbench;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Render/PartDesignWorkbench.svg;export-do;select-clear;
# select-by-id:PH_PartDesignWorkbench;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Legacy/PartDesignWorkbench.svg;export-do;select-clear;
#
# select-by-id:PH_PartDesign_CoordinateSystem;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Render/PartDesign_CoordinateSystem.svg;export-do;select-clear;
# select-by-id:PH_PartDesign_CoordinateSystem;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Legacy/PartDesign_CoordinateSystem.svg;export-do;select-clear;
#
# select-by-id:PH_PartDesign_Point;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Render/PartDesign_Point.svg;export-do;select-clear;
# select-by-id:PH_PartDesign_Point;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Legacy/PartDesign_Point.svg;export-do;select-clear;
#
# select-by-id:PH_PartDesign_SubtractivePrism;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Render/PartDesign_SubtractivePrism.svg;export-do;select-clear;
# select-by-id:PH_PartDesign_SubtractivePrism;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Legacy/PartDesign_SubtractivePrism.svg;export-do;select-clear;
#
# select-by-id:PH_PartDesign_Groove;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Render/PartDesign_Groove.svg;export-do;select-clear;
# select-by-id:PH_PartDesign_Groove;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Legacy/PartDesign_Groove.svg;export-do;select-clear;
#
# select-by-id:PH_PartDesign_Thickness;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Render/PartDesign_Thickness.svg;export-do;select-clear;
# select-by-id:PH_PartDesign_Thickness;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Legacy/PartDesign_Thickness.svg;export-do;select-clear;
#
# select-by-id:PH_PartDesign_Pad;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Render/PartDesign_Pad.svg;export-do;select-clear;
# select-by-id:PH_PartDesign_Pad;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Legacy/PartDesign_Pad.svg;export-do;select-clear;
#
# select-by-id:PH_PartDesign_Scaled;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Render/PartDesign_Scaled.svg;export-do;select-clear;
# select-by-id:PH_PartDesign_Scaled;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Legacy/PartDesign_Scaled.svg;export-do;select-clear;
#
# select-by-id:PH_PartDesign_AdditiveLoft;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Render/PartDesign_AdditiveLoft.svg;export-do;select-clear;
# select-by-id:PH_PartDesign_AdditiveLoft;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Legacy/PartDesign_AdditiveLoft.svg;export-do;select-clear;
#
# select-by-id:PH_Tree_PartDesign_Revolution;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Render/Tree_PartDesign_Revolution.svg;export-do;select-clear;
# select-by-id:PH_Tree_PartDesign_Revolution;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Legacy/Tree_PartDesign_Revolution.svg;export-do;select-clear;
#
# select-by-id:PH_PartDesign_SubtractiveLoft;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Render/PartDesign_SubtractiveLoft.svg;export-do;select-clear;
# select-by-id:PH_PartDesign_SubtractiveLoft;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Legacy/PartDesign_SubtractiveLoft.svg;export-do;select-clear;
#
# select-by-id:PH_PartDesign_AdditiveWedge;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Render/PartDesign_AdditiveWedge.svg;export-do;select-clear;
# select-by-id:PH_PartDesign_AdditiveWedge;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Legacy/PartDesign_AdditiveWedge.svg;export-do;select-clear;
#
# select-by-id:PH_PartDesign_Chamfer;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Render/PartDesign_Chamfer.svg;export-do;select-clear;
# select-by-id:PH_PartDesign_Chamfer;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Legacy/PartDesign_Chamfer.svg;export-do;select-clear;
#
# select-by-id:PH_PartDesign_Migrate;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Render/PartDesign_Migrate.svg;export-do;select-clear;
# select-by-id:PH_PartDesign_Migrate;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Legacy/PartDesign_Migrate.svg;export-do;select-clear;
#
# select-by-id:PH_PartDesign_SubtractiveCone;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Render/PartDesign_SubtractiveCone.svg;export-do;select-clear;
# select-by-id:PH_PartDesign_SubtractiveCone;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Legacy/PartDesign_SubtractiveCone.svg;export-do;select-clear;
#
# select-by-id:PH_PartDesign_MoveFeature;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Render/PartDesign_MoveFeature.svg;export-do;select-clear;
# select-by-id:PH_PartDesign_MoveFeature;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Legacy/PartDesign_MoveFeature.svg;export-do;select-clear;
#
# select-by-id:PH_PartDesign_ShapeBinder;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Render/PartDesign_ShapeBinder.svg;export-do;select-clear;
# select-by-id:PH_PartDesign_ShapeBinder;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Legacy/PartDesign_ShapeBinder.svg;export-do;select-clear;
#
# select-by-id:PH_PartDesign_Revolution;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Render/PartDesign_Revolution.svg;export-do;select-clear;
# select-by-id:PH_PartDesign_Revolution;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Legacy/PartDesign_Revolution.svg;export-do;select-clear;
#
# select-by-id:PH_PartDesign_Sprocket;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Render/PartDesign_Sprocket.svg;export-do;select-clear;
# select-by-id:PH_PartDesign_Sprocket;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Legacy/PartDesign_Sprocket.svg;export-do;select-clear;
#
# select-by-id:PH_PartDesign_AdditiveCone;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Render/PartDesign_AdditiveCone.svg;export-do;select-clear;
# select-by-id:PH_PartDesign_AdditiveCone;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Legacy/PartDesign_AdditiveCone.svg;export-do;select-clear;
#
# select-by-id:PH_PartDesign_SubtractiveHelix;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Render/PartDesign_SubtractiveHelix.svg;export-do;select-clear;
# select-by-id:PH_PartDesign_SubtractiveHelix;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Legacy/PartDesign_SubtractiveHelix.svg;export-do;select-clear;
#
# select-by-id:PH_PartDesign_AdditiveTorus;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Render/PartDesign_AdditiveTorus.svg;export-do;select-clear;
# select-by-id:PH_PartDesign_AdditiveTorus;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Legacy/PartDesign_AdditiveTorus.svg;export-do;select-clear;
#
# select-by-id:PH_PartDesign_Flip_Direction;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Render/PartDesign_Flip_Direction.svg;export-do;select-clear;
# select-by-id:PH_PartDesign_Flip_Direction;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Legacy/PartDesign_Flip_Direction.svg;export-do;select-clear;
#
# select-by-id:PH_PartDesign_AdditiveBox;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Render/PartDesign_AdditiveBox.svg;export-do;select-clear;
# select-by-id:PH_PartDesign_AdditiveBox;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Legacy/PartDesign_AdditiveBox.svg;export-do;select-clear;
#
# select-by-id:PH_PartDesign_SubShapeBinder;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Render/PartDesign_SubShapeBinder.svg;export-do;select-clear;
# select-by-id:PH_PartDesign_SubShapeBinder;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Legacy/PartDesign_SubShapeBinder.svg;export-do;select-clear;
#
# select-by-id:PH_PartDesign_Plane;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Render/PartDesign_Plane.svg;export-do;select-clear;
# select-by-id:PH_PartDesign_Plane;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Legacy/PartDesign_Plane.svg;export-do;select-clear;
#
# select-by-id:PH_PartDesign_AdditiveCylinder;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Render/PartDesign_AdditiveCylinder.svg;export-do;select-clear;
# select-by-id:PH_PartDesign_AdditiveCylinder;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Legacy/PartDesign_AdditiveCylinder.svg;export-do;select-clear;
#
# select-by-id:PH_PartDesign_SubtractiveBox;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Render/PartDesign_SubtractiveBox.svg;export-do;select-clear;
# select-by-id:PH_PartDesign_SubtractiveBox;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Legacy/PartDesign_SubtractiveBox.svg;export-do;select-clear;
#
# select-by-id:PH_PartDesign_LinearPattern;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Render/PartDesign_LinearPattern.svg;export-do;select-clear;
# select-by-id:PH_PartDesign_LinearPattern;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Legacy/PartDesign_LinearPattern.svg;export-do;select-clear;
#
# select-by-id:PH_PartDesign_Line;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Render/PartDesign_Line.svg;export-do;select-clear;
# select-by-id:PH_PartDesign_Line;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Legacy/PartDesign_Line.svg;export-do;select-clear;
#
# select-by-id:PH_PartDesign_Body_Tree;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Render/PartDesign_Body_Tree.svg;export-do;select-clear;
# select-by-id:PH_PartDesign_Body_Tree;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Legacy/PartDesign_Body_Tree.svg;export-do;select-clear;
#
# select-by-id:PH_PartDesign_SubtractiveTorus;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Render/PartDesign_SubtractiveTorus.svg;export-do;select-clear;
# select-by-id:PH_PartDesign_SubtractiveTorus;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Legacy/PartDesign_SubtractiveTorus.svg;export-do;select-clear;
#
# select-by-id:PH_PartDesign_Draft;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Render/PartDesign_Draft.svg;export-do;select-clear;
# select-by-id:PH_PartDesign_Draft;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Legacy/PartDesign_Draft.svg;export-do;select-clear;
#
# select-by-id:PH_PartDesign_AdditiveSphere;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Render/PartDesign_AdditiveSphere.svg;export-do;select-clear;
# select-by-id:PH_PartDesign_AdditiveSphere;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Legacy/PartDesign_AdditiveSphere.svg;export-do;select-clear;
#
# select-by-id:PH_PartDesign_AdditivePipe;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Render/PartDesign_AdditivePipe.svg;export-do;select-clear;
# select-by-id:PH_PartDesign_AdditivePipe;fit-canvas-to-selection;export-area-page;export-plain-svg;export-filename:Legacy/PartDesign_AdditivePipe.svg;export-do;select-clear;
